# %% [markdown]
# <a href="https://colab.research.google.com/github/maulifasekar/MachineLearningFundamental/blob/main/Praktikum2_G.231.21.0017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Untuk menggunakan pandas, import pandas sebagai pd

import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dddc6e16-4733-4d46-81f6-b7197b951f37" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dddc6e16-4733-4d46-81f6-b7197b951f37">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load the dataset
df = pd.read_csv('train.csv')

# menampilkan baris pertama dari baris ke-n pada dataset
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# memeriksa baris duplikat dalam DataFrame
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
# menampilkan informasi detail tentang dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#  menampilkan statistik deskriptif dari data frame atau series
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# memungkinkan pengindeksan dan penyimpanan indeks
# Categorical Colums
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :', cat_col)
# Numerical colums
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numerical columns :', num_col)
# Out:
# Categorical columns : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Numerical columns : ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# mengembalikan jumlah nilai unik untuk setiap kolom
df[cat_col].nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %%
# mengembalikan array yang berisi nilai unik pada sebuah dataset
df['Ticket'].unique()[:50]
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295'], dtype=object)

# %%
# menghapus label tertentu dari baris atau kolom
df1 = df.drop(columns=['Name', 'Ticket'])
df1.shape
# Out:
# (891, 10)

# %%
# membulatkan angka ke jumlah digit yang ditentukan
round((df1.isnull()).sum()/df1.shape[0]*100,2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
# menghapus/menghapus nilai yang hilang dari baris dan kolom
df2 = df1.drop(columns='Cabin')
df2.dropna(subset=['Embarked'], axis=0, inplace=True)
df2.shape
# Out:
# (889, 9)

# %%
# mengisi kolom (satu atau beberapa kolom)
#Mean Imputation
df3 = df2.fillna(df2.Age.mean())
# Let's Check the null values again
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# melakukan visualisasi data
import matplotlib.pyplot as plt

plt.boxplot(df3['Age'], vert=False)
plt.ylabel('Variable')
plt.xlabel('Age')
plt.title('Box Plot')
plt.show()

# %%
# mengimpor seluruh perpustakaan standar
from numpy.ma.core import std
#calculate summary statistics
mean = df3['Age'].mean()
std  = df3['Age'].std()

#calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

#Drop the outliers
df4 = df3[(df3['Age'] >= lower_bound) & (df3['Age'] <= upper_bound)]
# Out:
# Lower Bound : 3.7054001079256587
# Upper Bound : 55.57878528533277

# %%
# Menentukan variabel
x=df3[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
y=df3['Survived']

# %%
# menskalakan dan menerjemahkan setiap fitur satu per satu
from sklearn.preprocessing import MinMaxScaler

#initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#numerical columns
num_col_ = [col for col in x.columns if x[col].dtype != 'object']
x1 = x
#learning the statistical parameneters for each of the data and transforming
x1[num_col_] = scaler.fit_transform(x1[num_col_])
x1.head()
# Out:
# <ipython-input-27-7f9f5c4eecc8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1[num_col_] = scaler.fit_transform(x1[num_col_])
#    Pclass     Sex       Age  SibSp  Parch      Fare Embarked
# 0     1.0    male  0.271174  0.125    0.0  0.014151        S
# 1     0.0  female  0.472229  0.125    0.0  0.139136        C
# 2     1.0  female  0.321438  0.000    0.0  0.015469        S
# 3     0.0  female  0.434531  0.125    0.0  0.103644        S
# 4     1.0    male  0.434531  0.000    0.0  0.015713        S

# %%
# Untuk menggunakan pandas, import pandas sebagai pd
#import necessary modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-633d96fa-fd40-450f-9854-fc09d5382fe0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-633d96fa-fd40-450f-9854-fc09d5382fe0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#load the data set
data = pd.read_csv('creditcard.csv')
#print info about columns in the dataframe
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                --------------  -----
#  0   Time,"V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V11","V12","V13","V14","V15","V16","V17","V18","V19","V20","V21","V22","V23","V24","V25","V26","V27","V28","Amount","Class"  999 non-null    object
# dtypes: object(1)
# memory usage: 7.9+ KB
# None

# %%
# normalise the amount column
data['normAmount'] = StandardScaler().fit_transform(np.array(data['Amount']).reshape(-1, 1))

# drop time and amount columns as they are not relevant for prediction purpose
data = data.drop(['Time', 'Amount'], axis = 1)

# as you can see there are 492 fraund transaction.
data['Class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-70aeb6d0375e> in <cell line: 2>()
#       1 # normalise the amount column
# ----> 2 data['normAmount'] = StandardScaler().fit_transform(np.array(data['Amount']).reshape(-1, 1))
#       3
#       4 # drop time and amount columns as they are not relevant for prediction purpose
#       5 data = data.drop(['Time', 'Amount'], axis = 1)
#
# NameError: name 'StandardScaler' is not defined

# %%
from sklearn.model_selection import train_test_split

#Split into 70:30 ration
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

#describes info about train and test set
print("Number transactions X_train dataset :", x_train.shape)
print("Number transactions y_train dataset :", y_train.shape)
print("Number transactions X_train dataset :", x_test.shape)
print("Number transactions y_train dataset :", y_test.shape)
# Out:
# Number transactions X_train dataset : (622, 7)
# Number transactions y_train dataset : (622,)
# Number transactions X_train dataset : (267, 7)
# Number transactions y_train dataset : (267,)

# %%
# logistic regression object
lr = LogisticRegression()

#train the model on train set
lr.fit(x_train, y_train.ravel())

predictions = lr.predict(x_test)

#print Classification report
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-67cdf13a1026> in <cell line: 5>()
#       3
#       4 #train the model on train set
# ----> 5 lr.fit(x_train, y_train.ravel())
#       6
#       7 predictions = lr.predict(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 230
# Before OverSampling, counts of label '0': 392
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-d09e3e9f2886> in <cell line: 8>()
#       6 from imblearn.over_sampling import SMOTE
#       7 sm = SMOTE(random_state = 2)
# ----> 8 X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
#       9
#      10 print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
#
# AttributeError: 'SMOTE' object has no attribute 'fit_sample'

# %%
# logistic regression object
lr = LogisticRegression()

# train the model on train set 5 lr.fit(X_train, y_train.ravel())
lr.fit(X_train, y_train.ravel())

predictions = lr.predict(X_test)

# print classification report
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-e6177b5341bc> in <cell line: 5>()
#       3
#       4 # train the model on train set 5 lr.fit(X_train, y_train.ravel())
# ----> 5 lr.fit(X_train, y_train.ravel())
#       6
#       7 predictions = lr.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE (random_state = 2)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 230
# Before OverSampling, counts of label '0': 392
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-a8a624652416> in <cell line: 8>()
#       6 from imblearn.over_sampling import SMOTE
#       7 sm = SMOTE (random_state = 2)
# ----> 8 X_train_res, y_train_res = sm.fit_sample(X_train, y_train.ravel())
#       9
#      10 print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
#
# AttributeError: 'SMOTE' object has no attribute 'fit_sample'

# %%
 lr1 = LogisticRegression()

lr1.fit(X_train_res, y_train_res.ravel())
predictions = lr1.predict(X_test)

# print classification raport
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-15b40c0a480a> in <cell line: 3>()
#       1 lr1 = LogisticRegression()
#       2
# ----> 3 lr1.fit(X_train_res, y_train_res.ravel())
#       4 predictions = lr1.predict(X_test)
#       5
#
# NameError: name 'X_train_res' is not defined

# %%
print("Before Undersampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before Undersampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# apply near miss
from imblearn.under_sampling import NearMiss
nr = NearMiss()

X_train_miss, y_train_miss = nr.fit_sample(X_train, y_train.ravel())

print('After Undersampling, the shape of train_X: {}'.format(X_train_miss.shape))
print('After Undersampling, the shape of train_y: {} \n'.format(y_train_miss.shape))

print("After Undersampling, counts of label '1': {}".format(sum(y_train_miss ==1)))
print("After Undersampling, counts of label '0': {}".format(sum(y_train_miss == 0)))
# Out:
# Before Undersampling, counts of label '1': 230
# Before Undersampling, counts of label '0': 392
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-5fb91eb19e32> in <cell line: 8>()
#       6 nr = NearMiss()
#       7
# ----> 8 X_train_miss, y_train_miss = nr.fit_sample(X_train, y_train.ravel())
#       9
#      10 print('After Undersampling, the shape of train_X: {}'.format(X_train_miss.shape))
#
# AttributeError: 'NearMiss' object has no attribute 'fit_sample'

# %%
# train the model on train set
lr2 = LogisticRegression()
lr2.fit(X_train_miss, y_train_miss.ravel())
predictions = lr2.predict(X_test)

# print classification report
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-96-4627cee45b82> in <cell line: 3>()
#       1 # train the model on train set
#       2 lr2 = LogisticRegression()
# ----> 3 lr2.fit(X_train_miss, y_train_miss.ravel())
#       4 predictions = lr2.predict(X_test)
#       5
#
# NameError: name 'X_train_miss' is not defined
